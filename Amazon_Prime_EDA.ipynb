# %% [markdown]
# <a href="https://colab.research.google.com/github/Snehamn24/Amazon-Prime-Video-EDA-and-Machine-Learning-Analysis/blob/main/Amazon_Prime_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Project Name

# %% [markdown]
# Amazon Prime video : Exploratory Data Analysis(EDA)

# %% [markdown]
# ## Project Type

# %% [markdown]
#  EDA

# %% [markdown]
# # **Contribution**

# %% [markdown]
# Individual - Sneha M N

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# This project focuses on performing Exploratory Data Analysis (EDA) on the Amazon Prime Video dataset, which contains information about movies and TV shows available on the platform.
#
# This Project mainly includes 2 data sets
#
# * title.csv
#
# * Credits.csv
#
# ### 1. Objective
# The primary objective of this project is to analyze the Amazon Prime Video dataset to understand patterns, trends, and relationships within the data. The goal is to extract meaningful insights that can support data-driven decision-making.
#
# ### 2. Data Preparation
# The analysis begins with data understanding and cleaning. This includes handling missing values, removing duplicates, and correcting data types. The titles and credits datasets are merged using a common identifier, while carefully managing duplication caused by multiple actors per title.
#
# ### 3. Exploratory Data Analysis
# The EDA is performed in three stages:
# - **Univariate Analysis:** To study distributions of individual features such as IMDb scores, runtime, and release year.
# - **Bivariate Analysis:** To explore relationships between variables like ratings vs popularity and runtime vs scores.
# - **Multivariate Analysis:** To identify deeper patterns involving multiple variables such as trends over time and content type interactions.
#
# ### 4. Contributor & Regional Analysis
# The project also analyzes actors and directors to identify frequently appearing contributors. Additionally, production country analysis helps understand global content distribution trends.
#
# ### 5. Insights & Impact
# The analysis reveals key insights such as dominant genres, content growth trends, and factors affecting ratings and popularity. These insights can help improve content strategy, user engagement, and business decisions.
#
# ### 6. Conclusion
# Overall, this project transforms raw data into actionable insights and provides a strong foundation for further machine learning and predictive modeling.

# %% [markdown]
# # **GitHub Link**

# %% [markdown]
# https://github.com/Snehamn24/Amazon-Prime-Video-EDA-and-Machine-Learning-Analysis.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# With the rapid growth of streaming platforms, understanding content performance and audience preferences has become crucial. The Amazon Prime Video dataset contains detailed information about movies and TV shows with the important attributes .
# However, the raw data does not directly provide insights into which factors influence content success, audience engagement, or platform growth. Therefore, there is a need to systematically analyze this data to uncover hidden patterns, relationships, and trends.
#
# The problem is to explore and analyze the dataset to identify key factors affecting content ratings, popularity, and distribution, and to derive meaningful insights that can support better decision-making.

# %% [markdown]
# # **Business Objectives**

# %% [markdown]
# Identifying high-performing genres and content types
# - Understanding trends in content production over the years
# - Analyzing the relationship between ratings, votes, and popularity
# - Evaluating the impact of actors and directors on content success
# - Understanding regional distribution of content across countries
#
# The insights gained from this analysis can help in:
# - Making informed decisions about content acquisition and production
# - Improving recommendation systems
# - Enhancing user satisfaction and retention
# - Optimizing overall platform growth and performance

# %% [markdown]
# # **Let's Begin the  PROJECT !**

# %% [markdown]
# # ***1 . Know Your Data***

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset Loading

# %%
#titles
title = pd.read_csv(r"/content/titles.csv")
#credits
credits = pd.read_csv(r"/content/credits.csv")
print("Successfully dataset loaded")
# Out:
# Successfully dataset loaded

# %% [markdown]
# # Dataset First View

# %%
print("First 5 rows of the title dataset")
display(title.head())

print("\nFirst 5 rows of the credits dataset")
display(credits.head())
# Out:
# First 5 rows of the title dataset
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
# ...

# %% [markdown]
# # Dataset Rows & Columns count

# %%
print("Title dataset row and columns count")
r , c = title.shape
print("Row : ",r)
print("Column : " , c)
# Out:
# Title dataset row and columns count
# Row :  9871
# Column :  15

# %%
print("credits dataset row and columns count")
r , c = credits.shape
print("Row : ",r)
print("Column : " , c)
# Out:
# credits dataset row and columns count
# Row :  124235
# Column :  5

# %% [markdown]
# # Dataset Information

# %%
title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %% [markdown]
# # Duplicate Values

# %%
print("Number of duplicates in the title dataset " , title.duplicated().sum())
print("Number of duplicates in the credits dataset " , credits.duplicated().sum())
# Out:
# Number of duplicates in the title dataset  3
# Number of duplicates in the credits dataset  56

# %% [markdown]
# # Missing Values / Null Values

# %%
print("Null values in the title dataset\n" ,title.isnull().sum())
# Out:
# Null values in the title dataset
#  id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64

# %%
print("Null values in the credits dataset\n",credits.isnull().sum())
# Out:
# Null values in the credits dataset
#  person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %% [markdown]
# # Visualizing the missing count

# %%
# Visualizing missing values using heatmap
plt.figure(figsize=(12,6))
sns.heatmap(title.isnull(),cbar=False)
plt.title("Missing Values in Titles Dataset")
plt.show()

plt.figure(figsize=(12,6))
sns.heatmap(credits.isnull(), cbar=False)
plt.title("Missing Values in Credits Dataset")
plt.show()

# %% [markdown]
# ## What did you know about your dataset?
#
# The dataset consists of two main files: the title dataset and the credits dataset. The titles dataset contains
#
# * id
# * title
# * show type
# * description
# * release year
# * age-certification
# * runtime
# * genres
# * production countries
# * Seasons
# * imdb-id
# * imbd-scores
# * imbd-votes
# * tmbd-popularity
# * tmbd-score
#
# The credits dataset contains
# * person_id
# * id(title id)
# * name
# * character name
#
#
# From the initial exploration, it is observed that the dataset includes both numerical and categorical variables. Some columns contain missing values, which need to be handled appropriately during data cleaning. The presence of duplicate values is also checked to ensure data consistency.
#
# Additionally, the credits dataset contains multiple entries for a single title due to multiple actors and contributors, which may lead to duplication when merging both datasets. Therefore, careful handling is required during further analysis.
#
# Overall, the dataset is rich in information and suitable for performing detailed exploratory data analysis to uncover patterns, trends, and relationships.

# %% [markdown]
# # 2 . Understanding Your Variables

# %%
# Dataset Columns
print("Columns of the title dataset : ",title.columns)
# Out:
# Columns of the title dataset :  Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
print("Columns of the credits dataset : ",credits.columns)
# Out:
# Columns of the credits dataset :  Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
#Dataset Describe
#statistical summary of a numerical column

title.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9324.000000  7789.000000
# mean          6.910204     5.984247
# std          30.004098     1.517986
# min           0.000011     0.800000
# 25%           1.232000     5.100000
# 50%           2.536000     6.000000
# 75%           5.634000     6.900000
# ...

# %%
#  include categorical summary
title.describe(include='object')
# Out:
#              id           title   type         description age_certification  \
# count      9871            9871   9871                9752              3384
# unique     9868            9737      2                9734                11
# top     tm89134  The Lost World  MOVIE  No overview found.                 R
# freq          2               3   8514                   5              1249
#
#            genres production_countries    imdb_id
# count        9871                 9871       9204
# unique       2028                  497       9201
# top     ['drama']               ['US']  tt0033683
# freq          908                 4810          2

# %%
#dataset description for the credits dataset

#For the numerical values
credits.describe()
# Out:
#           person_id
# count  1.242350e+05
# mean   4.064737e+05
# std    5.616296e+05
# min    1.000000e+00
# 25%    3.899200e+04
# 50%    1.339490e+05
# 75%    5.712560e+05
# max    2.371153e+06

# %%
#for the categorical data
credits.describe(include = 'object')
# Out:
#               id                  name character    role
# count     124235                124235    107948  124235
# unique      8861                 79758     71097       2
# top     tm458582  George 'Gabby' Hayes   Himself   ACTOR
# freq         137                    49      1540  115846

# %% [markdown]
# # **Variable Description**

# %% [markdown]
# ## Variables Description
#
# The dataset consists of two dataframes: **titles** and **credits**, each containing different types of information about Amazon Prime Video content.
#
# ---
#
# ###  Titles Dataset
#
# The titles dataset contains **9871 entries** and **15 columns**, which include both numerical and categorical variables.
#
# ####  Categorical Variables (Object Type)
# - **id**: Unique identifier for each title
# - **title**: Name of the movie or TV show
# - **type**: Type of content (Movie or TV Show)
# - **description**: Brief overview of the content
# - **age_certification**: Age rating (e.g., PG, R)
# - **genres**: List of genres associated with the content
# - **production_countries**: Countries where the content was produced
# - **imdb_id**: Unique identifier from IMDb
#
# ####  Numerical Variables
# - **release_year** (int): Year the content was released
# - **runtime** (int): Duration of the content in minutes
# - **seasons** (float): Number of seasons (only for TV shows)
# - **imdb_score** (float): IMDb rating
# - **imdb_votes** (float): Number of votes on IMDb
# - **tmdb_popularity** (float): Popularity score on TMDB
# - **tmdb_score** (float): TMDB rating
#
# ---
#
# ###  Credits Dataset
#
# The credits dataset contains **124,235 entries** and **5 columns**, primarily focused on contributors.
#
# ####  Variables
# - **person_id**: Unique identifier for each person
# - **id**: Title identifier (used to link with titles dataset)
# - **name**: Name of the actor or director
# - **character**: Name of the character played (may contain missing values)
# - **role**: Role of the person (Actor or Director)
#
# ---
#
# ###  Key Observations
#
# - The dataset contains a mix of **categorical and numerical variables**, making it suitable for comprehensive analysis.
# - Several columns such as **age_certification, seasons, imdb_score, and tmdb_score** contain missing values and require preprocessing.
# - The **credits dataset has significantly more rows** than the titles dataset due to multiple contributors per title.
# - The **id column acts as a key** to merge both datasets.
# - Columns like **genres and production_countries** contain complex data (lists stored as strings), which may require further processing.
#
# ---
#
# ###  Conclusion
#
# The dataset is rich in information and provides multiple dimensions for analysis, including content type, ratings, contributors, and regional distribution. Proper handling of missing values and data types will be essential for accurate analysis.

# %% [markdown]
# # Check Unique Values for each variable.

# %%
# Unique values for the titles dataset
for col in title.columns:
    print(f"{col} - {title[col].nunique()} unique values")
# Out:
# id - 9868 unique values
# title - 9737 unique values
# type - 2 unique values
# description - 9734 unique values
# release_year - 110 unique values
# age_certification - 11 unique values
# runtime - 207 unique values
# genres - 2028 unique values
# production_countries - 497 unique values
# seasons - 32 unique values
# imdb_id - 9201 unique values
# imdb_score - 86 unique values
# imdb_votes - 3650 unique values
# tmdb_popularity - 5325 unique values
# tmdb_score - 89 unique values

# %%
# unique values for the credits dataset
for col in credits.columns:
  print(f"{col} - {credits[col].nunique()} unique values")
# Out:
# person_id - 80508 unique values
# id - 8861 unique values
# name - 79758 unique values
# character - 71097 unique values
# role - 2 unique values

# %% [markdown]
# # ***3 . Data Wrangling***

# %% [markdown]
# Data wrangling (or data munging) is the process of cleaning, structuring, and enriching raw, complex data into a usable format for analysis, machine learning, or visualization.

# %%
# 1 . Removing the Duplicates
title.drop_duplicates(inplace=True)
credits.drop_duplicates(inplace=True)

# %%
# check for the duplicates now
print("Number of Duplicates in the titles dataset",title.duplicated().sum())

print("\nNumber of Duplicates in the credits dataset",credits.duplicated().sum())
# Out:
# Number of Duplicates in the titles dataset 0
#
# Number of Duplicates in the credits dataset 0

# %%
# 2. Handling missing values
title.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6484
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8511
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2080
# dtype: int64

# %% [markdown]
# ### Missing Values Analysis (Titles Dataset)
#
# From the analysis of missing values in the titles dataset, the following observations are made:
#
# - **description** has 119 missing values, which is relatively small and can be ignored or filled with a placeholder.
# - **age_certification** has 6484 missing values, indicating that a large portion of content does not have age ratings available.
# - **seasons** has 8511 missing values, which is expected since this column is only applicable to TV shows and not movies.
# - **imdb_id** has 667 missing values, suggesting incomplete linkage with IMDb records.
# - **imdb_score** and **imdb_votes** have over 1000 missing values, which may impact rating-based analysis.
# - **tmdb_popularity** and **tmdb_score** also contain missing values, though comparatively fewer.
#
# ### Key Insight
#
# Missing values are concentrated in specific columns rather than being randomly distributed. Some missing values are logical (e.g., seasons for movies), while others indicate incomplete data.
#
# ### Conclusion
#
# Appropriate handling strategies such as imputation, replacement, or column removal are required to ensure data quality before analysis.

# %%
# Fill description with placeholder
title['description']=title['description'].fillna("No description available")

# Fill age certification
title['age_certification']=title['age_certification'].fillna("Unknown")

#Drop seasons (not useful for all rows)
title.drop(columns=['seasons'], inplace=True)


# Fill ratings with median
title['imdb_score']=title['imdb_score'].fillna(title['imdb_score'].median())
title['tmdb_score'] = title['tmdb_score'].fillna(title['tmdb_score'].median())


# Fill votes/popularity with 0
title['imdb_votes'] = title['imdb_votes'].fillna(0)
title['tmdb_popularity'] = title['tmdb_popularity'].fillna(0)

# %%
#check for the null values
title.isna().sum()
# Out:
# id                        0
# title                     0
# type                      0
# description               0
# release_year              0
# age_certification         0
# runtime                   0
# genres                    0
# production_countries      0
# imdb_id                 667
# imdb_score                0
# imdb_votes                0
# tmdb_popularity           0
# tmdb_score                0
# dtype: int64

# %% [markdown]
# ### Handling Missing Values in imdb_id
#
# The imdb_id column contains 667 missing values. Since this column is only an identifier and does not contribute to analysis or insights, it was removed from the dataset to maintain data cleanliness and avoid unnecessary processing.

# %%
# missing values in the credits dataset
credits.isnull().sum()
# Out:
# person_id        0
# id               0
# name             0
# character    16277
# role             0
# dtype: int64

# %%
#filling the missing values in the character column
credits['character'] = credits['character'].fillna('Unknown')

# %% [markdown]
# ### Missing Values in Credits Dataset
#
# The credits dataset contains missing values only in the "character" column, with 16,277 null entries.
#
# This is expected because:
# - Not all contributors have character roles (e.g., directors)
# - Some records may not include character details
#
# Since this column is not critical for the current analysis, the missing values were either retained or replaced with "Unknown" without affecting the overall analysis.

# %% [markdown]
# What all manipulations have you done and insights you found ?
#
# ## Data Wrangling: Manipulations & Insights
#
# ###  Data Manipulations Performed
#
# - **Duplicate Handling:** Checked for duplicate records in both titles and credits datasets and removed them to ensure data consistency.
# - **Missing Value Treatment:**
#   - Filled missing values in **description** with a placeholder ("No description available").
#   - Replaced missing values in **age_certification** with "Unknown".
#   - Imputed missing values in **imdb_score** and **tmdb_score** using median values to avoid skewness.
#   - Replaced missing values in **imdb_votes** and **tmdb_popularity** with 0.
#   - Dropped the **imdb_id** column as it is an identifier and not useful for analysis.
#   - Handled missing values in the **character** column in the credits dataset appropriately.
# - **Data Cleaning:**
#   - Removed unnecessary spaces in text columns.
#   - Ensured correct data types for numerical and categorical variables.
# - **Dataset Merging:**
#   - Merged the titles and credits datasets using the common **id** column to combine content and contributor information.
# - **Feature Engineering:**
#   - Created a new feature **content_age** to analyze how recent the content is.
#
# ---
#
# ###  Key Insights
#
# - Missing values were concentrated in specific columns rather than randomly distributed.
# - The **seasons** column had a large number of missing values, indicating it is relevant only for TV shows.
# - The dataset contains **multiple entries per title** after merging due to multiple actors and contributors.
# - A large portion of content lacks **age certification**, indicating incomplete metadata.
# - The dataset is rich in features such as ratings, genres, and popularity, making it suitable for detailed analysis.
# - Some missing values are **contextual (expected)** rather than errors, such as missing character names or seasons.
#
# ---
#
# ### Conclusion
#
# Data wrangling improved the quality, consistency, and usability of the dataset. Proper handling of missing values, removal of irrelevant columns, and merging of datasets ensured that the data is ready for effective exploratory data analysis and further modeling.

# %% [markdown]
# # ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ## Chart - 1

# %%
# visualization code Distribution Of Content Type(univariate)

plt.figure(figsize = (8,5))
sns.countplot(x='type',data=title)
plt.title("Distribution of Content Type (Movies vs TV Shows)")
plt.xlabel("Content Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot is used to visualize the distribution of categorical variables. In this case, it helps to understand how the content is distributed between movies and TV shows on the platform. This is a fundamental step in exploratory data analysis to understand the dataset composition.

# %% [markdown]
# ###### 2 . What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the dataset is heavily dominated by movies compared to TV shows. Movies constitute a significantly larger portion of the content, while TV shows are relatively fewer in number. This indicates that the platform has a stronger focus on movie content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight helps in understanding the content strategy of the platform.
#
# Positive Impact:
# - A large collection of movies can attract users who prefer quick and diverse entertainment options.
# - Helps the platform maintain a strong library of standalone content.
#
# Negative Impact:
# - A lower number of TV shows may reduce long-term user engagement, as TV series typically encourage binge-watching and higher retention.
# - This imbalance might lead to missed opportunities in capturing audiences who prefer episodic content.
#
# Therefore, the platform can consider increasing TV show content to improve user engagement and retention.

# %% [markdown]
# ## Chart 2

# %%
# Visualization code Content Release Trend(Univariate)

plt.figure(figsize=(10,5))
sns.histplot(title['release_year'], bins=30, kde=True)
plt.title("Distribution of Content Release Year")
plt.xlabel("Release Year")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart

# %% [markdown]
# A histogram is used to understand the distribution of numerical variables. In this case, it helps analyze how content production is spread across different years and identifies trends in content release over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that content production has increased significantly in recent years. Most of the content is concentrated after the year 2000, with a noticeable peak in the last decade.
#
# This indicates that the platform contains more modern content compared to older titles, reflecting a growing trend in content creation and digital streaming.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight is useful for understanding content trends and user preferences.
#
# Positive Impact:
# - A higher number of recent releases aligns with current audience preferences for modern content.
# - Helps in attracting younger audiences and maintaining relevance in the competitive streaming market.
#
# Negative Impact:
# - Limited older content may reduce appeal for users who prefer classic or vintage movies.
# - Over-dependence on recent content may reduce content diversity.
#
# The platform can maintain a balance between new and classic content to cater to a wider audience.

# %% [markdown]
# ## Chart - 3

# %%
# Chart - 3: IMDb Score Distribution (Univariate)

plt.figure(figsize=(10,5))
sns.histplot(title['imdb_score'], bins=30, kde=True)
plt.title("Distribution of IMDb Scores")
plt.xlabel("IMDb Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is used to analyze the distribution of numerical variables. IMDb score is a key metric that reflects audience ratings, and this chart helps in understanding how content is rated overall on the platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows the distribution of IMDb scores across all titles. The x-axis represents the IMDb rating (ranging from 0 to 10), while the y-axis represents the number of titles corresponding to each rating range.
#
# The chart indicates that most of the content is concentrated between ratings 5 and 7, meaning a large number of titles have moderate ratings. The highest frequency occurs around this mid-range, showing that average-rated content dominates the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight helps evaluate content quality on the platform.
#
# Positive Impact:
# - A large number of moderately rated titles indicates consistent content quality.
# - Helps in maintaining a stable user experience.
#
# Negative Impact:
# - Fewer highly rated titles may reduce the platform's ability to attract premium audiences.
# - Lack of top-rated content can impact brand perception and competitiveness.
#
# The platform can focus on acquiring or producing higher-rated content to improve overall quality and user satisfaction.

# %% [markdown]
# ## Chart-4

# %%
# Chart - 4: Top Genres

# Convert string to list
title['genres'] = title['genres'].apply(lambda x: eval(x))

# Explode genres into separate rows
genres_exploded = title.explode('genres')

# Count top genres
top_genres = genres_exploded['genres'].value_counts().head(10)

# Plot
plt.figure(figsize=(10,5))
sns.barplot(x=top_genres.values, y=top_genres.index)
plt.title("Top 10 Most Common Genres")
plt.xlabel("Count")
plt.ylabel("Genres")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used to compare different categories. In this case, it helps identify the most common genres available on the platform, making it easier to understand content distribution across categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that certain genres like drama, comedy, and action are more dominant compared to others. This indicates that the platform focuses more on these popular genres, while niche genres have less representation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight helps in understanding audience preferences and content strategy.
#
# Positive Impact:
# - Focusing on popular genres like drama and comedy helps attract a larger audience.
# - Ensures higher engagement as these genres are widely preferred.
#
# Negative Impact:
# - Over-reliance on a few genres may reduce content diversity.
# - Users interested in niche genres may feel underserved, leading to reduced satisfaction.
#
# The platform can maintain a balance by including both popular and niche genres to cater to a wider audience.

# %% [markdown]
# ## Chart 5

# %%
#Bivariate Analysis
# Chart - 5: IMDb Score vs TMDB Popularity

plt.figure(figsize=(10,5))
sns.scatterplot(x='imdb_score', y='tmdb_popularity', data=title)
plt.title("Relationship between IMDb Score and TMDB Popularity")
plt.xlabel("IMDb Score")
plt.ylabel("TMDB Popularity")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is used to analyze the relationship between two numerical variables. This chart helps in understanding whether higher-rated content (IMDb score) is also more popular (TMDB popularity).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows a scattered distribution, indicating that there is no strong linear relationship between IMDb score and TMDB popularity.
#
# Some content with high ratings does not necessarily have high popularity, and some moderately rated content appears to be highly popular. This suggests that popularity is influenced by factors beyond just ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight highlights an important aspect of content performance.
#
# Positive Impact:
# - Moderately rated content can still become popular, indicating opportunities for wider audience reach.
# - Popularity is influenced by factors such as marketing, trends, and star cast, not just quality.
#
# Negative Impact:
# - High-quality content may not always gain visibility, leading to underutilization of good content.
# - Over-reliance on popularity metrics may overlook genuinely high-quality titles.
#
# The platform should focus on promoting high-quality content effectively while also analyzing additional factors that drive popularity.

# %% [markdown]
# ## Chart - 6

# %%
#Chart – 6: Top Actors by Number of Appearances
actors = credits[credits['role'] == 'ACTOR']
top_actors = actors['name'].value_counts().head(20)
plt.figure(figsize=(10,5))
sns.barplot(x=top_actors.values, y=top_actors.index)
plt.title("Top 20 Actors by Number of Appearances")
plt.xlabel("Number of Appearances")
plt.ylabel("Actor Name")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick this chart?

# %% [markdown]
# A bar chart is used to compare categorical data. This chart helps identify the most frequently appearing actors in the dataset, providing insights into contributor involvement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that a few actors appear in a large number of titles, while most actors have fewer appearances. This indicates that certain actors are highly active or frequently featured on the platform.

# %% [markdown]
# ##### 3. Business Impact

# %% [markdown]
# This insight helps in understanding the influence of actors on content production.
#
# Positive Impact:
# - Frequently appearing actors may attract loyal audiences and increase viewership.
# - Helps in identifying popular contributors for future collaborations.
#
# Negative Impact:
# - Over-reliance on a limited number of actors may reduce content diversity.
# - May limit opportunities for new talent.
#
# The platform can balance between popular actors and emerging talent to maintain diversity and engagement.

# %% [markdown]
# ## Chart - 7

# %%
#Chart – 7: Average IMDb Score by Top Directors

#merge the datasets
df = pd.merge(title, credits, on='id', how='left')

#Filter Directors
directors = df[df['role'] == 'DIRECTOR']

#top directors
top_directors = directors.groupby('name').filter(lambda x: len(x) >= 5)

#average IMDB Scores
director_ratings = top_directors.groupby('name')['imdb_score'].mean().sort_values(ascending=False).head(10)

#plot
plt.figure(figsize=(10,5))
sns.barplot(x=director_ratings.values, y=director_ratings.index)
plt.title("Top Directors by Average IMDb Score")
plt.xlabel("Average IMDb Score")
plt.ylabel("Director Name")
plt.show()

# %% [markdown]
# ###### 1. Why did you pick this chart?

# %% [markdown]
# A bar chart is used to compare categorical entities. This chart helps identify directors who consistently produce high-quality content based on average IMDb ratings.

# %% [markdown]
# ###### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that certain directors have consistently higher average IMDb scores compared to others. This indicates that some directors are more successful in producing high-quality content.

# %% [markdown]
# ##### 3. Business Impact

# %% [markdown]
# This insight helps in identifying high-performing directors.
#
# Positive Impact:
# - Helps in selecting directors who consistently produce high-rated content.
# - Improves content quality and audience satisfaction.
#
# Negative Impact:
# - Over-reliance on a few directors may limit diversity in storytelling.
# - May reduce opportunities for new directors.
#
# The platform can collaborate with high-performing directors while also encouraging new talent to maintain diversity.

# %% [markdown]
# ## Chart - 9

# %%
# Chart – 9: Runtime Distribution using Boxplot
plt.figure(figsize=(8,5))
sns.boxplot(x=title['runtime'])
plt.title("Runtime Distribution of Content")
plt.xlabel("Runtime (minutes)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick this chart?

# %% [markdown]
# A boxplot is used to visualize the distribution of numerical data and detect outliers. It helps in understanding the spread and central tendency of runtime values.

# %% [markdown]
# ##### 2. Insights

# %% [markdown]
# The boxplot shows that most content falls within a certain runtime range, while some titles have very high or very low runtimes, indicating the presence of outliers.
#
# This suggests that while most content follows standard duration patterns, a few titles deviate significantly.

# %% [markdown]
# ###### 3. Business Impact

# %% [markdown]
# Positive Impact:
# - Helps in identifying standard content duration preferred by the platform.
#
# Negative Impact:
# - Extremely long or short content may not align with user preferences.
#
# The platform can optimize content duration based on user engagement patterns.

# %% [markdown]
# ## Chart 10

# %%
# Top Production Countries (Regional Analysis)
import ast

# Step 1: Safe conversion (string → list only when needed)
title['production_countries'] = title['production_countries'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

# Step 2: Explode list into separate rows
country_exploded = title.explode('production_countries')

# Step 3: Remove missing values (important in real datasets)
country_exploded = country_exploded.dropna(subset=['production_countries'])

# Step 4: Count occurrences
top_countries = country_exploded['production_countries'].value_counts().head(10)

# Step 5: Visualization
plt.figure(figsize=(10, 6))
plt.pie(top_countries, labels=top_countries.index, autopct='%1.1f%%', startangle=90)
plt.title("Top Production Countries Distribution")
plt.show()

# %% [markdown]
# ###### 1. Why did you pick this chart?

# %% [markdown]
# A pie chart is used to show the proportion of categories. This chart helps in understanding how content is distributed across different countries, highlighting regional production trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that a few countries contribute the majority of the content, with countries like the US dominating production. Other countries contribute smaller portions, indicating uneven global distribution.
#
# This suggests that the platform relies heavily on content from specific regions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact:
# - Strong content from dominant countries ensures consistent quality and audience familiarity.
#
# Negative Impact:
# - Over-reliance on a few regions may limit global diversity.
# - Users from other regions may feel underrepresented.
#
# The platform can expand content from diverse regions to attract a wider global audience and improve inclusivity.

# %% [markdown]
# ## Chart 11 - Correlation Heatmap

# %%
# Select only numeric columns
numeric_cols = df.select_dtypes(include=['float64', 'int64'])

plt.figure(figsize=(10,6))
sns.heatmap(numeric_cols.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick this chart?

# %% [markdown]
# A correlation heatmap is used to understand the relationship between numerical variables in the dataset. It helps identify whether variables are positively or negatively related, which is useful for detecting patterns and dependencies.

# %% [markdown]
# ##### 2. Insights from the chart

# %% [markdown]
# IMDb score and IMDb votes may show a moderate positive correlation, meaning popular movies tend to have higher ratings.
# Runtime may have weak or no correlation with ratings.
# Some variables show little to no relationship, indicating independence.

# %% [markdown]
# ## Chart - 15 - Pair Plot

# %%
sns.pairplot(df[['imdb_score', 'imdb_votes', 'runtime']])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick this chart?

# %% [markdown]
# A pair plot helps visualize relationships between multiple numerical variables simultaneously. It shows both scatter plots and distributions, making it easier to detect trends, clusters, and outliers.

# %% [markdown]
# ##### 2. Insights from the chart

# %% [markdown]
# 1.  A positive trend can be observed between IMDb votes and IMDb score.
# 2. Presence of outliers in votes (very high popularity movies).
# 3. Data is not perfectly linear, indicating multiple influencing factors.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the exploratory data analysis performed on the dataset, the following key recommendations are suggested to help the client achieve their business objectives effectively:
#
# 1. Focus on Highly Rated and Highly Voted Content
#
# Movies with high IMDb scores and high vote counts indicate both quality and popularity.
# The client should prioritize such content for promotion, recommendations, and visibility to maximize user satisfaction and engagement.
#
# 2. Invest in Successful Directors and Genres
#
# Certain directors and genres consistently perform better in terms of ratings and audience response.
# The client should invest more in these high-performing directors and genres to increase the success rate of future content.
#
# 3. Promote High Engagement Movies
#
# Movies with high IMDb votes represent strong audience interaction and interest.
# These titles should be promoted more on the platform to increase visibility, watch time, and user retention.
#
# 4. Data-Driven Content Recommendation
#
# Use insights from ratings, popularity, genres, and runtime patterns to recommend content that aligns with user preferences and viewing trends. This will improve personalization and enhance user experience on the platform.
#
#  5. Balance Quality and Popularity
#
# It is important to maintain a balance between high-quality content (ratings) and popular content (votes and engagement).
# A combined strategy ensures both critical acclaim and mass audience appeal.
#
#  6. Improve Overall Content Strategy
#
# The platform should continuously analyze performance metrics to guide content creation, acquisition, and recommendation strategies.
# This will help in increasing user engagement, retention, and overall platform growth.
#
# Final Outcome
#
# By focusing on high-rated and high-voted content, investing in successful creators and genres, promoting engaging movies, and using data-driven recommendations, the client can significantly improve content strategy, user satisfaction, and overall business performance.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The Exploratory Data Analysis (EDA) of the movies and TV shows dataset provided meaningful insights into content distribution, audience engagement, and overall platform performance. The analysis helped in understanding key patterns such as the dominance of certain content types, variation in IMDb ratings, runtime distribution, and engagement levels through votes and popularity metrics.
#
# It was observed that highly rated and highly voted titles tend to attract more audience attention, indicating that both quality and popularity play a crucial role in content success. Additionally, certain genres and content types consistently perform better, highlighting the importance of focused content creation and acquisition strategies.
#
# The EDA also revealed the importance of proper data cleaning, as inconsistencies like missing values and improper formatting can significantly affect analysis outcomes.
#
# Overall, the insights derived from this analysis can help improve content recommendation systems, optimize content strategy, and enhance user engagement. By leveraging data-driven decision-making, the platform can better align its offerings with user preferences and market trends, ultimately leading to improved business performance and customer satisfaction.
